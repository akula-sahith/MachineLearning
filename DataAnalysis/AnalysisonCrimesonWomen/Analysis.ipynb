# %%
#Importing the libraries required
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('WomenCrimeData.csv')

# %%
df
# Out:
#      S.NO             STATES  YEAR  RAPE  KIDNAP & ABDUCTION  DOWRY DEATHS  \
# 0       1     Andhra Pradesh  2011  1442                1612           599
# 1       2  Arunachal Pradesh  2011    42                  60             0
# 2       3              Assam  2011  1700                3192           121
# 3       4              Bihar  2011   934                3050          1413
# 4       5       Chhattisgarh  2011  1053                 365           104
# ..    ...                ...   ...   ...                 ...           ...
# 391    32         D&N Haveli  2021  1250                4083           141
# 392    33        Daman & Diu  2021   315                 904            16
# 393    34           Delhi UT  2021     2                   1             0
# 394    35        Lakshadweep  2021     0                   0             0
# 395    36         Puducherry  2021     2                   0             2
#
#      CRUETLY BY HUSBAND OR HIS RELATIVES  HUMAN TRAFFICKING  \
# ...

# %%
df.head(5)
# Out:
#    S.NO             STATES  YEAR  RAPE  KIDNAP & ABDUCTION  DOWRY DEATHS  \
# 0     1     Andhra Pradesh  2011  1442                1612           599
# 1     2  Arunachal Pradesh  2011    42                  60             0
# 2     3              Assam  2011  1700                3192           121
# 3     4              Bihar  2011   934                3050          1413
# 4     5       Chhattisgarh  2011  1053                 365           104
#
#    CRUETLY BY HUSBAND OR HIS RELATIVES  HUMAN TRAFFICKING  ASSAULT ON MODESTY  \
# 0                                13376                  0                   0
# 1                                   18                  0                   0
# 2                                 5246                  2                   0
# 3                                 2607                 10                   0
# 4                                  834                  2                   0
#
# ...

# %%
year_wise_crimes = df.groupby('YEAR')['TOTAL CRIMES AGAINST WOMEN'].sum()
year_wise_crimes.plot(kind='bar',color='red',xlabel='year',ylabel='Number of crimes',title='Year wise crimes')
# Out:
# <Axes: title={'center': 'Year wise crimes'}, xlabel='year', ylabel='Number of crimes'>

# %%
year_wise_rapes = df.groupby('YEAR')['RAPE'].sum()
year_wise_rapes.plot(kind='bar',xlabel='Year',ylabel='Number of rapes')
# Out:
# <Axes: xlabel='Year', ylabel='Number of rapes'>

# %%
df.head(0)
# Out:
# Empty DataFrame
# Columns: [S.NO, STATES, YEAR, RAPE, KIDNAP & ABDUCTION, DOWRY DEATHS, CRUETLY BY HUSBAND OR HIS RELATIVES, HUMAN TRAFFICKING, ASSAULT ON MODESTY, SEXUAL HARRASSMENT, IMORTAL TRAFFICKING, TOTAL CRIMES AGAINST WOMEN]
# Index: []

# %%
#State wise crime analysis 
state_wise_crimes = df.groupby('STATES')['TOTAL CRIMES AGAINST WOMEN'].sum()
plt.figure(figsize=(15,15))
state_wise_crimes.plot(kind='bar',xlabel="State",ylabel='Number of crimes')
# Out:
# <Axes: xlabel='State', ylabel='Number of crimes'>

# %%
df.head(5)
# Out:
#    S.NO             STATES  YEAR  RAPE  KIDNAP & ABDUCTION  DOWRY DEATHS  \
# 0     1     Andhra Pradesh  2011  1442                1612           599
# 1     2  Arunachal Pradesh  2011    42                  60             0
# 2     3              Assam  2011  1700                3192           121
# 3     4              Bihar  2011   934                3050          1413
# 4     5       Chhattisgarh  2011  1053                 365           104
#
#    CRUETLY BY HUSBAND OR HIS RELATIVES  HUMAN TRAFFICKING  ASSAULT ON MODESTY  \
# 0                                13376                  0                   0
# 1                                   18                  0                   0
# 2                                 5246                  2                   0
# 3                                 2607                 10                   0
# 4                                  834                  2                   0
#
# ...

# %%
states = set(df['STATES'])
for state in states:
    print(state)
    state_wise_data = df[df['STATES']==state]
    print(state_wise_data)
    sns.lineplot(x='YEAR',y='TOTAL CRIMES AGAINST WOMEN',data=state_wise_data,marker='x')
    plt.show()
# Out:
# Karnataka
# Arunachal Pradesh
# Bihar
# Maharashtra
# D&N Haveli
# Puducherry
# West Bengal
# Gujarat
# Uttarakhand
# Delhi UT
# Meghalaya
# A & N Islands
# Uttar Pradesh
# Rajasthan
# Jammu & Kashmir
# Haryana
# Daman & Diu
# Lakshadweep
# Manipur
# Madhya Pradesh
# Nagaland
# Tripura
# Tamil Nadu
# Mizoram
# Kerala
# Odisha
# Goa
# Sikkim
# Chhattisgarh
# Chandigarh
# Jharkhand
# Punjab
# Andhra Pradesh
# Telangana
# Assam
# Himachal Pradesh

# %%
states = set(df['STATES'])
for state in states:
    print(state)
    state_wise_data = df[df['STATES']==state]
    sns.lineplot(x='YEAR',y='RAPE',data=state_wise_data,marker='x')
    plt.title(state)
    plt.show()
# Out:
# Karnataka
# Arunachal Pradesh
# Bihar
# Maharashtra
# D&N Haveli
# Puducherry
# West Bengal
# Gujarat
# Uttarakhand
# Delhi UT
# Meghalaya
# A & N Islands
# Uttar Pradesh
# Rajasthan
# Jammu & Kashmir
# Haryana
# Daman & Diu
# Lakshadweep
# Manipur
# Madhya Pradesh
# Nagaland
# Tripura
# Tamil Nadu
# Mizoram
# Kerala
# Odisha
# Goa
# Sikkim
# Chhattisgarh
# Chandigarh
# Jharkhand
# Punjab
# Andhra Pradesh
# Telangana
# Assam
# Himachal Pradesh

# %%
df.head(0)
# Out:
# Empty DataFrame
# Columns: [S.NO, STATES, YEAR, RAPE, KIDNAP & ABDUCTION, DOWRY DEATHS, CRUETLY BY HUSBAND OR HIS RELATIVES, HUMAN TRAFFICKING, ASSAULT ON MODESTY, SEXUAL HARRASSMENT, IMORTAL TRAFFICKING, TOTAL CRIMES AGAINST WOMEN]
# Index: []

# %%
print("Average number of crimes happening in india per year")
year_wise_average_crimes = df.groupby('YEAR')['TOTAL CRIMES AGAINST WOMEN'].mean()
year_wise_average_crimes.plot(kind='line',ylabel='Average number of crimes',title='Average')
plt.show()
year_wise_average_crimes.plot(kind='bar',ylabel='Average number of crimes',title='Average')
plt.show()
# Out:
# Average number of crimes happening in india per year

# %%
df.head(5)
# Out:
#    S.NO             STATES  YEAR  RAPE  KIDNAP & ABDUCTION  DOWRY DEATHS  \
# 0     1     Andhra Pradesh  2011  1442                1612           599
# 1     2  Arunachal Pradesh  2011    42                  60             0
# 2     3              Assam  2011  1700                3192           121
# 3     4              Bihar  2011   934                3050          1413
# 4     5       Chhattisgarh  2011  1053                 365           104
#
#    CRUETLY BY HUSBAND OR HIS RELATIVES  HUMAN TRAFFICKING  ASSAULT ON MODESTY  \
# 0                                13376                  0                   0
# 1                                   18                  0                   0
# 2                                 5246                  2                   0
# 3                                 2607                 10                   0
# 4                                  834                  2                   0
#
# ...

# %%
for state in states:
    state_wise_dowry_deaths = df[df['STATES']==state]
    print(state)
    sns.lineplot(x='YEAR',y='DOWRY DEATHS',data=state_wise_dowry_deaths)
    plt.show()
# Out:
# Karnataka
# Arunachal Pradesh
# Bihar
# Maharashtra
# D&N Haveli
# Puducherry
# West Bengal
# Gujarat
# Uttarakhand
# Delhi UT
# Meghalaya
# A & N Islands
# Uttar Pradesh
# Rajasthan
# Jammu & Kashmir
# Haryana
# Daman & Diu
# Lakshadweep
# Manipur
# Madhya Pradesh
# Nagaland
# Tripura
# Tamil Nadu
# Mizoram
# Kerala
# Odisha
# Goa
# Sikkim
# Chhattisgarh
# Chandigarh
# Jharkhand
# Punjab
# Andhra Pradesh
# Telangana
# Assam
# Himachal Pradesh

# %%
df.head(5)
# Out:
#    S.NO             STATES  YEAR  RAPE  KIDNAP & ABDUCTION  DOWRY DEATHS  \
# 0     1     Andhra Pradesh  2011  1442                1612           599
# 1     2  Arunachal Pradesh  2011    42                  60             0
# 2     3              Assam  2011  1700                3192           121
# 3     4              Bihar  2011   934                3050          1413
# 4     5       Chhattisgarh  2011  1053                 365           104
#
#    CRUETLY BY HUSBAND OR HIS RELATIVES  HUMAN TRAFFICKING  ASSAULT ON MODESTY  \
# 0                                13376                  0                   0
# 1                                   18                  0                   0
# 2                                 5246                  2                   0
# 3                                 2607                 10                   0
# 4                                  834                  2                   0
#
# ...

# %%
print("Number of sexual harrasments in each for each year : ")
for state in states:
    print(state)
    state_wise_sexual_harrasments_data = df[df['STATES']==state]
    sns.barplot(x='YEAR',y='SEXUAL HARRASSMENT',data=state_wise_sexual_harrasments_data)
    plt.show()
# Out:
# Number of sexual harrasments in each for each year :
# Karnataka
# Arunachal Pradesh
# Bihar
# Maharashtra
# D&N Haveli
# Puducherry
# West Bengal
# Gujarat
# Uttarakhand
# Delhi UT
# Meghalaya
# A & N Islands
# Uttar Pradesh
# Rajasthan
# Jammu & Kashmir
# Haryana
# Daman & Diu
# Lakshadweep
# Manipur
# Madhya Pradesh
# Nagaland
# Tripura
# Tamil Nadu
# Mizoram
# Kerala
# Odisha
# Goa
# Sikkim
# Chhattisgarh
# Chandigarh
# Jharkhand
# Punjab
# Andhra Pradesh
# Telangana
# Assam
# Himachal Pradesh

# %%
df.head(0)
# Out:
# Empty DataFrame
# Columns: [S.NO, STATES, YEAR, RAPE, KIDNAP & ABDUCTION, DOWRY DEATHS, CRUETLY BY HUSBAND OR HIS RELATIVES, HUMAN TRAFFICKING, ASSAULT ON MODESTY, SEXUAL HARRASSMENT, IMORTAL TRAFFICKING, TOTAL CRIMES AGAINST WOMEN]
# Index: []

# %%
print("Average number of sexual harrassments happening in india every year : ")
averagenumber_of_sexual_harrasments = df.groupby('YEAR')['SEXUAL HARRASSMENT'].mean()
averagenumber_of_sexual_harrasments.plot(kind='bar',ylabel='Average number of sexual harrassments every year')
# Out:
# Average number of sexual harrassments happening in india every year :
# <Axes: xlabel='YEAR', ylabel='Average number of sexual harrassments every year'>

# %%
# Out:
# 30
