# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('sales_data.csv')
df
# Out:
#      Transaction ID        Date Product Category  \
# 0             10001  2024-01-01      Electronics
# 1             10002  2024-01-02  Home Appliances
# 2             10003  2024-01-03         Clothing
# 3             10004  2024-01-04            Books
# 4             10005  2024-01-05  Beauty Products
# ..              ...         ...              ...
# 235           10236  2024-08-23  Home Appliances
# 236           10237  2024-08-24         Clothing
# 237           10238  2024-08-25            Books
# 238           10239  2024-08-26  Beauty Products
# 239           10240  2024-08-27           Sports
#
#                                         Product Name  Units Sold  Unit Price  \
# 0                                      iPhone 14 Pro           2      999.99
# 1                                   Dyson V11 Vacuum           1      499.99
# 2                                   Levi's 501 Jeans           3       69.99
# ...

# %%
df.head(10)
# Out:
#    Transaction ID        Date Product Category                 Product Name  \
# 0           10001  2024-01-01      Electronics                iPhone 14 Pro
# 1           10002  2024-01-02  Home Appliances             Dyson V11 Vacuum
# 2           10003  2024-01-03         Clothing             Levi's 501 Jeans
# 3           10004  2024-01-04            Books            The Da Vinci Code
# 4           10005  2024-01-05  Beauty Products      Neutrogena Skincare Set
# 5           10006  2024-01-06           Sports  Wilson Evolution Basketball
# 6           10007  2024-01-07      Electronics          MacBook Pro 16-inch
# 7           10008  2024-01-08  Home Appliances         Blueair Classic 480i
# 8           10009  2024-01-09         Clothing             Nike Air Force 1
# 9           10010  2024-01-10            Books        Dune by Frank Herbert
#
#    Units Sold  Unit Price  Total Revenue         Region Payment Method
# ...

# %%
product_category_revenue = df.groupby('Product Category')['Total Revenue'].sum()
product_category_revenue.plot(kind='bar',color='green')
# Out:
# <Axes: xlabel='Product Category'>

# %%
explodes = [0 for i in range(len(product_category_revenue))]
k = 0
for i in product_category_revenue:
    if i == max(product_category_revenue):
        explodes[k] = 0.2
    else:
        explodes[k] = 0
    k += 1
product_category_revenue.plot(kind='pie',autopct='%1.1f%%',shadow=True)
# Out:
# <Axes: ylabel='Total Revenue'>

# %%
payment_type_total_revenue = df.groupby('Payment Method')['Total Revenue'].sum()
payment_type_total_revenue.plot(kind='bar',grid=True)
print(payment_type_total_revenue)
# Out:
# Payment Method
# Credit Card    51170.86
# Debit Card      8128.93
# PayPal         21268.06
# Name: Total Revenue, dtype: float64

# %%
# product_wise_revenue = df.groupby('')
df.head()
# Out:
#    Transaction ID        Date Product Category             Product Name  \
# 0           10001  2024-01-01      Electronics            iPhone 14 Pro
# 1           10002  2024-01-02  Home Appliances         Dyson V11 Vacuum
# 2           10003  2024-01-03         Clothing         Levi's 501 Jeans
# 3           10004  2024-01-04            Books        The Da Vinci Code
# 4           10005  2024-01-05  Beauty Products  Neutrogena Skincare Set
#
#    Units Sold  Unit Price  Total Revenue         Region Payment Method
# 0           2      999.99        1999.98  North America    Credit Card
# 1           1      499.99         499.99         Europe         PayPal
# 2           3       69.99         209.97           Asia     Debit Card
# 3           4       15.99          63.96  North America    Credit Card
# 4           1       89.99          89.99         Europe         PayPal

# %%
product_category_revenue = df.groupby('Product Category')['Total Revenue'].agg(['mean','sum'])
product_category_revenue.plot(kind='bar',xlabel='Product',ylabel=['mean','sum'],color=['blue','orange'])
# Out:
# <Axes: xlabel='Product', ylabel='[mean, sum]'>

# %%
df.head(0)
# Out:
# Empty DataFrame
# Columns: [Transaction ID, Date, Product Category, Product Name, Units Sold, Unit Price, Total Revenue, Region, Payment Method]
# Index: []

# %%
units_sold_in_each_category = df.groupby('Product Category')['Units Sold'].sum()
units_sold_in_each_category.plot(kind='bar')
# Out:
# <Axes: xlabel='Product Category'>

# %%
df.head(0)
# Out:
# Empty DataFrame
# Columns: [Transaction ID, Date, Product Category, Product Name, Units Sold, Unit Price, Total Revenue, Region, Payment Method]
# Index: []

# %%
df.head(5)
# Out:
#    Transaction ID        Date Product Category             Product Name  \
# 0           10001  2024-01-01      Electronics            iPhone 14 Pro
# 1           10002  2024-01-02  Home Appliances         Dyson V11 Vacuum
# 2           10003  2024-01-03         Clothing         Levi's 501 Jeans
# 3           10004  2024-01-04            Books        The Da Vinci Code
# 4           10005  2024-01-05  Beauty Products  Neutrogena Skincare Set
#
#    Units Sold  Unit Price  Total Revenue         Region Payment Method
# 0           2      999.99        1999.98  North America    Credit Card
# 1           1      499.99         499.99         Europe         PayPal
# 2           3       69.99         209.97           Asia     Debit Card
# 3           4       15.99          63.96  North America    Credit Card
# 4           1       89.99          89.99         Europe         PayPal

# %%
revenue_by_region = df.groupby('Region')['Total Revenue'].sum()
revenue_by_region.plot(kind='bar',color='red')
# Out:
# <Axes: xlabel='Region'>

# %%
labels = ['Asia','Europe','North America']
explodes = [0,0,0.2]
plt.pie(revenue_by_region,labels=labels,explode=explodes,shadow=True)
# Out:
# ([<matplotlib.patches.Wedge at 0x1a58e11fad0>,
# ...
#  [Text(0.7045828060526063, 0.8447266240713831, 'Asia'),
#   Text(-0.9313562099277165, 0.5852995901494205, 'Europe'),
#   Text(0.17383497347149982, -1.288325037402504, 'North America')])

# %%
df.head(10)
# Out:
#    Transaction ID        Date Product Category                 Product Name  \
# 0           10001  2024-01-01      Electronics                iPhone 14 Pro
# 1           10002  2024-01-02  Home Appliances             Dyson V11 Vacuum
# 2           10003  2024-01-03         Clothing             Levi's 501 Jeans
# 3           10004  2024-01-04            Books            The Da Vinci Code
# 4           10005  2024-01-05  Beauty Products      Neutrogena Skincare Set
# 5           10006  2024-01-06           Sports  Wilson Evolution Basketball
# 6           10007  2024-01-07      Electronics          MacBook Pro 16-inch
# 7           10008  2024-01-08  Home Appliances         Blueair Classic 480i
# 8           10009  2024-01-09         Clothing             Nike Air Force 1
# 9           10010  2024-01-10            Books        Dune by Frank Herbert
#
#    Units Sold  Unit Price  Total Revenue         Region Payment Method
# ...

# %%
# Out:
# 10
